# %%
import pandas as pd
import matplotlib.pyplot as plt
import os
from utils_grafo import ler_arquivo_dat

arquivo = "../selected_instances/BHW2.dat"

grafo = ler_arquivo_dat(arquivo)

estatisticas = {
    "Total de Vértices": len(grafo.vertices),
    "Total de Arestas": len(grafo.arestas),
    "Total de Arcos": len(grafo.arcos),
    "Vértices Requeridos": len(grafo.vertices_req),
    "Arestas Requeridas": len(grafo.arestas_req),
    "Arcos Requeridos": len(grafo.arcos_req),
    "Densidade": grafo.densidade_grafo(),
    "Grau Mínimo": grafo.grau_minimo(),
    "Grau Máximo": grafo.grau_maximo(),
    "Caminho Médio": grafo.caminho_medio(),
    "Diâmetro": grafo.diametro(),
}

df = pd.DataFrame(estatisticas.items(), columns=["Métrica", "Valor"])
display(df.style.set_caption(f"📌 Estatísticas da Instância: {os.path.basename(arquivo)}").set_properties(**{'text-align': 'left'}))
 
metricas_numericas = {k: v for k, v in estatisticas.items() if isinstance(v, (int, float))}

plt.figure(figsize=(10, 6))
plt.bar(metricas_numericas.keys(), metricas_numericas.values(), color='skyblue')
plt.title(f"Estatísticas da Instância: {os.path.basename(arquivo)}", fontsize=14)
plt.ylabel("Valor")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()


intermediacao = grafo.mostra_intermediacao()
# Out:
# <style type="text/css">
# #T_0491f_row0_col0, #T_0491f_row0_col1, #T_0491f_row1_col0, #T_0491f_row1_col1, #T_0491f_row2_col0, #T_0491f_row2_col1, #T_0491f_row3_col0, #T_0491f_row3_col1, #T_0491f_row4_col0, #T_0491f_row4_col1, #T_0491f_row5_col0, #T_0491f_row5_col1, #T_0491f_row6_col0, #T_0491f_row6_col1, #T_0491f_row7_col0, #T_0491f_row7_col1, #T_0491f_row8_col0, #T_0491f_row8_col1, #T_0491f_row9_col0, #T_0491f_row9_col1, #T_0491f_row10_col0, #T_0491f_row10_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_0491f">
#   <caption>📌 Estatísticas da Instância: BHW2.dat</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0491f_level0_col0" class="col_heading level0 col0" >Métrica</th>
#       <th id="T_0491f_level0_col1" class="col_heading level0 col1" >Valor</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0491f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0491f_row0_col0" class="data row0 col0" >Total de Vértices</td>
#       <td id="T_0491f_row0_col1" class="data row0 col1" >12.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0491f_row1_col0" class="data row1 col0" >Total de Arestas</td>
#       <td id="T_0491f_row1_col1" class="data row1 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0491f_row2_col0" class="data row2 col0" >Total de Arcos</td>
#       <td id="T_0491f_row2_col1" class="data row2 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0491f_row3_col0" class="data row3 col0" >Vértices Requeridos</td>
#       <td id="T_0491f_row3_col1" class="data row3 col1" >4.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_0491f_row4_col0" class="data row4 col0" >Arestas Requeridas</td>
#       <td id="T_0491f_row4_col1" class="data row4 col1" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_0491f_row5_col0" class="data row5 col0" >Arcos Requeridos</td>
#       <td id="T_0491f_row5_col1" class="data row5 col1" >25.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_0491f_row6_col0" class="data row6 col0" >Densidade</td>
#       <td id="T_0491f_row6_col1" class="data row6 col1" >0.189394</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_0491f_row7_col0" class="data row7 col0" >Grau Mínimo</td>
#       <td id="T_0491f_row7_col1" class="data row7 col1" >3.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_0491f_row8_col0" class="data row8 col0" >Grau Máximo</td>
#       <td id="T_0491f_row8_col1" class="data row8 col1" >6.000000</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_0491f_row9_col0" class="data row9 col0" >Caminho Médio</td>
#       <td id="T_0491f_row9_col1" class="data row9 col1" >29.568182</td>
#     </tr>
#     <tr>
#       <th id="T_0491f_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_0491f_row10_col0" class="data row10 col0" >Diâmetro</td>
#       <td id="T_0491f_row10_col1" class="data row10 col1" >72.000000</td>
#     </tr>
#   </tbody>
# </table>
# Intermediação:
# Nó 1: 40
# Nó 10: 29
# Nó 11: 15
# Nó 12: 46
# Nó 2: 23
# Nó 3: 18
# Nó 4: 6
# Nó 5: 38
# Nó 6: 38
# Nó 7: 3
# Nó 8: 3
# Nó 9: 12
